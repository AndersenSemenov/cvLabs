# %%
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('resources/Gora-Beluha.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2HSV)

plt.imshow(img), plt.show()
cv.imwrite('resources/hsv.jpg', img_gray)
# Out:
# True
